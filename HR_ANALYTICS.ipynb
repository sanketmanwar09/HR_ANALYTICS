# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df= pd.read_csv("C:/Users/DELL/Desktop/ANALYTICS PROJECT/HR ANALYTICS/New folder/HR_2.csv")
df
# Out:
#        Employee ID  MonthlyIncome  MonthlyRate  NumCompaniesWorked Over18  \
# 0                6          41552      1246560                   3      Y
# 1                7           5303       148484                   3      Y
# 2                8          28555       571100                   2      Y
# 3               11          10587        95283                   0      Y
# 4               13          34153       648907                   7      Y
# ...            ...            ...          ...                 ...    ...
# 49995        49987          15828       189936                   0      Y
# 49996        49989          39017      1092476                   4      Y
# 49997        49990          37010       777210                   0      Y
# 49998        49992          11508       172620                   2      Y
# 49999        49993          43567        43567                   6      Y
#
#       OverTime  PercentSalaryHike  PerformanceRating  \
# ...

# %%
df1= pd.read_csv("C:/Users/DELL/Desktop/ANALYTICS PROJECT/HR ANALYTICS/New folder/HR_1.csv")
df1
# Out:
#        Age Attrition BusinessTravel  DailyRate              Department  \
# 0       31        No     Non-Travel        158                Software
# 1       38        No  Travel_Rarely        985         Human Resources
# 2       59       Yes     Non-Travel       1273                   Sales
# 3       52       Yes  Travel_Rarely        480                 Support
# 4       32        No     Non-Travel        543         Human Resources
# ...    ...       ...            ...        ...                     ...
# 49995   55       Yes  Travel_Rarely       1226  Research & Development
# 49996   39       Yes  Travel_Rarely       1201         Human Resources
# 49997   44        No  Travel_Rarely        232                Software
# 49998   49        No  Travel_Rarely       1390         Human Resources
# 49999   50       Yes  Travel_Rarely        861                   Sales
#
#        DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
df.head()
# Out:
#    Employee Id  MonthlyIncome  MonthlyRate  NumCompaniesWorked Over18  \
# 0            6          41552      1246560                   3      Y
# 1            7           5303       148484                   3      Y
# 2            8          28555       571100                   2      Y
# 3           11          10587        95283                   0      Y
# 4           13          34153       648907                   7      Y
#
#   OverTime  PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 0      Yes                 15                  4                         3
# 1       No                 45                  4                         1
# 2      Yes                 35                  3                         2
# 3      Yes                 47                  4                         2
# 4       No                 17                  1                         3
#
#    StandardHours  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# ...

# %%
df1.head()
# Out:
#    Age Attrition BusinessTravel  DailyRate       Department  DistanceFromHome  \
# 0   31        No     Non-Travel        158         Software                 7
# 1   38        No  Travel_Rarely        985  Human Resources                33
# 2   59       Yes     Non-Travel       1273            Sales                 5
# 3   52       Yes  Travel_Rarely        480          Support                 2
# 4   32        No     Non-Travel        543  Human Resources                 7
#
#    Education    EducationField  EmployeeCount  EmployeeNumber  \
# 0          3           Medical              1               1
# 1          5     Life Sciences              1               2
# 2          2  Technical Degree              1               3
# 3          5         Marketing              1               4
# 4          5   Human Resources              1               5
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
df.shape
# Out:
# (50000, 18)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      50000 non-null  int64
#  1   Attrition                50000 non-null  object
#  2   BusinessTravel           50000 non-null  object
#  3   DailyRate                50000 non-null  int64
#  4   Department               50000 non-null  object
#  5   DistanceFromHome         50000 non-null  int64
#  6   Education                50000 non-null  int64
#  7   EducationField           50000 non-null  object
#  8   EmployeeCount            50000 non-null  int64
#  9   EmployeeNumber           50000 non-null  int64
#  10  EnvironmentSatisfaction  50000 non-null  int64
#  11  Gender                   50000 non-null  object
#  12  HourlyRate               50000 non-null  int64
#  13  JobInvolvement           50000 non-null  int64
# ...

# %%
df.describe()
# Out:
#         Employee Id  MonthlyIncome   MonthlyRate  NumCompaniesWorked  \
# count  50000.000000    50000.00000  5.000000e+04        50000.000000
# mean   25000.500000    26015.78126  4.040436e+05            3.999000
# std    14433.901067    14410.97750  3.401908e+05            2.582373
# min        1.000000     1001.00000  1.007000e+03            0.000000
# 25%    12500.750000    13519.75000  1.228410e+05            2.000000
# 50%    25000.500000    25988.50000  3.106300e+05            4.000000
# 75%    37500.250000    38460.25000  6.105750e+05            6.000000
# max    50000.000000    50999.00000  1.528290e+06            8.000000
#
#        PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# count        50000.00000       50000.000000              50000.000000
# mean            24.61832           2.495960                  2.502220
# std             14.40500           1.118092                  1.117918
# ...

# %%
df1.describe(include="O")
# Out:
#        Attrition BusinessTravel Department EducationField Gender  \
# count      50000          50000      50000          50000  50000
# unique         2              3          6              6      2
# top          Yes     Non-Travel      Sales        Medical   Male
# freq       25105          16919       8453           8607  25059
#
#                 JobRole MaritalStatus
# count             50000         50000
# unique               10             3
# top     Sales Executive        Single
# freq               5053         16703

# %% [markdown]
# ## Average Attrition rate Department wise

# %%
avg_attrition_rate = df1.groupby('Department')['Attrition'].apply(lambda x: (x == 'Yes').mean() * 100)
avg_attrition_rate
# Out:
# Department
# Hardware                  49.443016
# Human Resources           49.857448
# Research & Development    51.208078
# Sales                     50.017745
# Software                  50.539827
# Support                   50.186635
# Name: Attrition, dtype: float64

# %%
plt.figure(figsize=(10, 6))
avg_attrition_rate.plot(kind='bar', color='blue')
plt.title('Average Attrition Rate by Department')
plt.xlabel('Department')
plt.ylabel('Attrition Rate (%)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %%
df1.describe(include="O")
# Out:
#        Attrition BusinessTravel Department EducationField Gender  \
# count      50000          50000      50000          50000  50000
# unique         2              3          6              6      2
# top          Yes     Non-Travel      Sales        Medical   Male
# freq       25105          16919       8453           8607  25059
#
#                 JobRole MaritalStatus
# count             50000         50000
# unique               10             3
# top     Sales Executive        Single
# freq               5053         16703

# %% [markdown]
# ## Average Hourly rate of Female Research Director

# %%
female_research_director = df1[(df1['Gender'] == 'Female') & (df1['JobRole'] == 'Research Director')]
female_research_director
# Out:
#        Age Attrition     BusinessTravel  DailyRate              Department  \
# 5       19       Yes         Non-Travel        779                Hardware
# 60      20        No  Travel_Frequently        462                Hardware
# 61      42       Yes         Non-Travel        109                   Sales
# 86      39        No         Non-Travel        124  Research & Development
# 107     60        No  Travel_Frequently        691  Research & Development
# ...    ...       ...                ...        ...                     ...
# 49958   60        No  Travel_Frequently       1256                Software
# 49973   19       Yes         Non-Travel       1136         Human Resources
# 49981   56        No      Travel_Rarely       1295                 Support
# 49995   55       Yes      Travel_Rarely       1226  Research & Development
# 49999   50       Yes      Travel_Rarely        861                   Sales
#
# ...

# %%
average_hourly_rate_female_rd = female_research_director['HourlyRate'].mean()
average_hourly_rate_female_rd
# Out:
# 116.31171383647799

# %%
df = df.rename(columns={'Employee ID' :'Employee Id'})
df.head()
# Out:
#    Employee Id  MonthlyIncome  MonthlyRate  NumCompaniesWorked Over18  \
# 0            6          41552      1246560                   3      Y
# 1            7           5303       148484                   3      Y
# 2            8          28555       571100                   2      Y
# 3           11          10587        95283                   0      Y
# 4           13          34153       648907                   7      Y
#
#   OverTime  PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 0      Yes                 15                  4                         3
# 1       No                 45                  4                         1
# 2      Yes                 35                  3                         2
# 3      Yes                 47                  4                         2
# 4       No                 17                  1                         3
#
#    StandardHours  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# ...

# %%
df1 = df1.rename(columns={'EmployeeNumber' :'Employee Id'})
df1.head()
# Out:
#    Age Attrition BusinessTravel  DailyRate       Department  DistanceFromHome  \
# 0   31        No     Non-Travel        158         Software                 7
# 1   38        No  Travel_Rarely        985  Human Resources                33
# 2   59       Yes     Non-Travel       1273            Sales                 5
# 3   52       Yes  Travel_Rarely        480          Support                 2
# 4   32        No     Non-Travel        543  Human Resources                 7
#
#    Education    EducationField  EmployeeCount  Employee Id  \
# 0          3           Medical              1            1
# 1          5     Life Sciences              1            2
# 2          2  Technical Degree              1            3
# 3          5         Marketing              1            4
# 4          5   Human Resources              1            5
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
merged_df = pd.merge(df, df1, on='Employee Id', how='inner')

merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Employee Id               50000 non-null  int64
#  1   MonthlyIncome             50000 non-null  int64
#  2   MonthlyRate               50000 non-null  int64
#  3   NumCompaniesWorked        50000 non-null  int64
#  4   Over18                    50000 non-null  object
#  5   OverTime                  50000 non-null  object
#  6   PercentSalaryHike         50000 non-null  int64
#  7   PerformanceRating         50000 non-null  int64
#  8   RelationshipSatisfaction  50000 non-null  int64
#  9   StandardHours             50000 non-null  int64
#  10  StockOptionLevel          50000 non-null  int64
#  11  TotalWorkingYears         50000 non-null  int64
#  12  TrainingTimesLastYear     50000 non-null  int64
#  13  WorkLifeBalance           50000 non-null  int64
# ...

# %% [markdown]
# ## Attrition rate Vs Monthly income stats

# %%
Attrition_MI = merged_df.groupby('Attrition')['MonthlyIncome'].mean()
Attrition_MI
# Out:
# Attrition
# No     25958.486443
# Yes    26072.596813
# Name: MonthlyIncome, dtype: float64

# %%
plt.figure(figsize=(4, 3))
plt.pie(Attrition_MI, labels=Attrition_MI.index, autopct='%1.1f%%', startangle=140, colors=['skyblue', 'salmon'])
plt.title('Distribution of Monthly Income by Attrition')
plt.axis('equal')  
plt.show()

# %% [markdown]
# ## Average working years for each Department

# %%
average_departments_working_years= merged_df.groupby('Department')['TotalWorkingYears'].mean()
average_departments_working_years
# Out:
# Department
# Hardware                  20.479373
# Human Resources           20.453671
# Research & Development    20.298473
# Sales                     20.617769
# Software                  20.645274
# Support                   20.484527
# Name: TotalWorkingYears, dtype: float64

# %%
plt.figure(figsize=(10, 6))
bars = average_departments_working_years.plot(kind='bar', color='green')
plt.title('Average Total Working Years by Department')
plt.xlabel('Department')
plt.ylabel('Average Total Working Years')
plt.xticks(rotation=45, ha='right')

# Add value labels on the bars
for bar in bars.patches:
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), round(bar.get_height(), 2),
             ha='center', va='bottom')

plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ## Job Role Vs Work life balance

# %%
merged_df['WorkLifeBalance'].head()
# Out:
# 0    2
# 1    4
# 2    2
# 3    4
# 4    2
# Name: WorkLifeBalance, dtype: int64

# %%
work_life_balance_by_job_role = merged_df.groupby('JobRole')['WorkLifeBalance'].count()
work_life_balance_by_job_role
# Out:
# JobRole
# Developer                    4985
# Healthcare Representative    5045
# Human Resources              4928
# Laboratory Technician        4912
# Manager                      5036
# Manufacturing Director       4974
# Research Director            5024
# Research Scientist           5024
# Sales Executive              5053
# Sales Representative         5019
# Name: WorkLifeBalance, dtype: int64

# %%
plt.figure(figsize=(10, 6))
bars = work_life_balance_by_job_role.plot(kind='bar', color='teal')
plt.title('Work-Life Balance Ratings by Job Role')
plt.xlabel('Job Role')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')

for bar in bars.patches:
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), bar.get_height(),
             ha='center', va='bottom')

plt.tight_layout()

plt.show()
